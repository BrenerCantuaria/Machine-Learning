# %% [markdown]
# # I
# ### Dataset
# #### - Definição das colunas
# #### - Partições
# #### - Pre-processamento (Limpeza, Transformação)
#
# # II
# #### X_train
# #### Y_train
# ##### Inferências
# ###### Y_test
#
#
# # III
# #### Avaliação do model

# %% [markdown]
# ### Classificação

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
iris = load_iris(as_frame=True)
df_iris = iris.frame

# %%
df_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
X_iris = df_iris.drop('target',axis = 1)
Y_iris = df_iris['target']

# %%
X_iris.shape,Y_iris.shape
# Out:
# ((150, 4), (150,))

# %%
X_train_iris,X_test_iris,Y_train_iris,Y_test_iris = train_test_split(X_iris,Y_iris,test_size = 0.3, random_state = 0)

# %%
X_train_iris.shape, X_test_iris.shape, Y_train_iris.shape, Y_test_iris.shape
# Out:
# ((105, 4), (45, 4), (105,), (45,))

# %% [markdown]
# # Modelo Tree

# %%
modelo_tree = DecisionTreeClassifier(random_state = 0)

# %%
modelo_tree
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ### Treinando modelo

# %%
modelo_tree.fit(X_train_iris,Y_train_iris)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ### Predição é feita com o valores de teste

# %%
y_preds_iris = modelo_tree.predict(X_test_iris)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
acuraria_tree = accuracy_score(Y_test_iris,y_preds_iris)

# %%
print('Acurácia árvore de decisão: ', acuraria_tree)
# Out:
# Acurácia árvore de decisão:  0.9777777777777777

# %% [markdown]
# # Nova partição treino/teste 80/20

# %%
X_train_iris,X_test_iris,Y_train_iris,Y_test_iris = train_test_split(X_iris,Y_iris,test_size = 0.2, random_state = 0)

# %%
X_train_iris.shape, X_test_iris.shape, Y_train_iris.shape, Y_test_iris.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %%
modelo_tree = DecisionTreeClassifier(random_state = 0)

# %%
modelo_tree.fit(X_train_iris,Y_train_iris)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_preds_iris = modelo_tree.predict(X_test_iris)

# %%
acuraria_tree = accuracy_score(Y_test_iris,y_preds_iris)

# %%
print('Acurácia árvore de decisão: ', acuraria_tree)
# Out:
# Acurácia árvore de decisão:  1.0

# %%
from sklearn import tree

# %%
tree.plot_tree(modelo_tree)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.665\nsamples = 120\nvalue = [39, 37, 44]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.496\nsamples = 81\nvalue = [0, 37, 44]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.18\nsamples = 40\nvalue = [0, 36, 4]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
# ...

# %% [markdown]
# # Modelo RandomForest

# %%
modelo_rf = RandomForestClassifier(n_estimators = 100,random_state = 0)

# %%
modelo_rf.fit(X_train_iris,Y_train_iris)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# # Predição

# %%
y_preds_iris_rf = modelo_rf.predict(X_test_iris)

# %%
acuraria_rf = accuracy_score(Y_test_iris,y_preds_iris_rf)

# %% [markdown]
# # Acurácia RandomForest

# %%
print('Acurácia Random Forest: ', acuraria_tree)
# Out:
# Acurácia Random Forest:  1.0

# %% [markdown]
# # Rregressão Logística

# %%
modelo_rl = LogisticRegression(random_state = 0)

# %%
modelo_rl.fit(X_train_iris,Y_train_iris)
# Out:
# LogisticRegression(random_state=0)

# %%
y_preds_rl_iris = modelo_rl.predict(X_test_iris)

# %%
acuracia_rl = accuracy_score(Y_test_iris,y_preds_rl_iris)

# %%
print('Acurácia regressão logística: ', acuracia_rl)
# Out:
# Acurácia regressão logística:  1.0

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

# %%
n = 3 
knn = KNN(n_neighbors = n)

# %%
knn.fit(X_train_iris,Y_train_iris)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_preds_iris = knn.predict(X_test_iris)

# %%
acuraria_knn = accuracy_score(Y_test_iris,y_preds_iris)

# %%
print('Acurácia KNN: ',acuraria_knn)
# Out:
# Acurácia KNN:  0.9666666666666667

# %% [markdown]
# # Relatário de classificação

# %%
print(classification_report(Y_test_iris,y_preds_iris))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.92      0.96        13
#            2       0.86      1.00      0.92         6
#
#     accuracy                           0.97        30
#    macro avg       0.95      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # Matriz de confusão:

# %%
print(confusion_matrix(Y_test_iris, y_preds_iris))
# Out:
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
